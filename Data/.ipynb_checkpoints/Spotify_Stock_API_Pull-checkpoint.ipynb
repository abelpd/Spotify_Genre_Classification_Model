# %%
import requests
import json
import pandas as pd

# %%
api_key = 'CRYUALQWFMWHEG9S'

# %%
#https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=SPOT&outputsize=full&apikey=demo

SPOT_data = requests.get('https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=SPOT&outputsize=full&apikey='+ api_key)

# %%
SPOT_data2 = SPOT_data.json()

# %%
SPOT_data2['Time Series (Daily)'].keys()
# Out:
# dict_keys(['2019-07-09', '2019-07-08', '2019-07-05', '2019-07-03', '2019-07-02', '2019-07-01', '2019-06-28', '2019-06-27', '2019-06-26', '2019-06-25', '2019-06-24', '2019-06-21', '2019-06-20', '2019-06-19', '2019-06-18', '2019-06-17', '2019-06-14', '2019-06-13', '2019-06-12', '2019-06-11', '2019-06-10', '2019-06-07', '2019-06-06', '2019-06-05', '2019-06-04', '2019-06-03', '2019-05-31', '2019-05-30', '2019-05-29', '2019-05-28', '2019-05-24', '2019-05-23', '2019-05-22', '2019-05-21', '2019-05-20', '2019-05-17', '2019-05-16', '2019-05-15', '2019-05-14', '2019-05-13', '2019-05-10', '2019-05-09', '2019-05-08', '2019-05-07', '2019-05-06', '2019-05-03', '2019-05-02', '2019-05-01', '2019-04-30', '2019-04-29', '2019-04-26', '2019-04-25', '2019-04-24', '2019-04-23', '2019-04-22', '2019-04-18', '2019-04-17', '2019-04-16', '2019-04-15', '2019-04-12', '2019-04-11', '2019-04-10', '2019-04-09', '2019-04-08', '2019-04-05', '2019-04-04', '2019-04-03', '2019-04-02', '2019-04-01', '2019-03-29', '2019-0
# ...

# %%
df.head()
# Out:
#                             Meta Data.1. Information Meta Data.2. Symbol  \
# 0  Daily Prices (open, high, low, close) and Volumes                SPOT
#
#   Meta Data.3. Last Refreshed Meta Data.4. Output Size Meta Data.5. Time Zone  \
# 0                  2019-07-09                Full size             US/Eastern
#
#   Time Series (Daily).2018-04-03.1. open  \
# 0                               165.9000
#
#   Time Series (Daily).2018-04-03.2. high  \
# 0                               169.0000
#
#   Time Series (Daily).2018-04-03.3. low  \
# 0                              148.2600
#
#   Time Series (Daily).2018-04-03.4. close  \
# 0                                149.0100
#
#   Time Series (Daily).2018-04-03.5. volume  ...  \
# 0                                 30526507  ...
#
#   Time Series (Daily).2019-07-08.1. open  \
# 0                               145.3700
#
#   Time Series (Daily).2019-07-08.2. high  \
# 0                               145.4225
#
# ...
