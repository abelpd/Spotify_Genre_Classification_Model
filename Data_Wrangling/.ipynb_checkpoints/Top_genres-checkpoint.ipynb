# %%
#importing modules
import pandas as pd
import csv
import spotipy
import spotipy.util as util
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy.oauth2 as oauth2
import numpy as np
import os
from API_KEYS import grab_api_keys
import pickle
from collections import defaultdict

# %%
#IMPORTANT - URL for songs is too long, an adjustment to pandas settings is required
pd.set_option("display.max_colwidth", 10000)

#grabbing API keys from hidden file
CLIENT_ID, SECRET_CLIENT_ID = grab_api_keys()

# %%
credentials = oauth2.SpotifyClientCredentials(
        client_id=CLIENT_ID,
        client_secret=SECRET_CLIENT_ID)

token = credentials.get_access_token()
spotify = spotipy.Spotify(auth=token)

# %%
cwd = os.getcwd()
print (cwd)
# Out:
# C:\Users\abels\Desktop\spotify_scrape\Data

# %%
df = pd.read_csv(cwd + r'\final_csv_files\Combined_Top_200_Stream_Numbers.csv')

# %%
df['Streams'] = pd.to_numeric(df['Streams'], errors='coerce')
mask = (~np.isnan(df['Streams']))
df = df[mask]

# %%
df.head()
# Out:
#    Unnamed: 0 Position                               Track Name  \
# 1           1        1                                  Starboy
# 2           2        2                                   Closer
# 3           3        3                          Let Me Love You
# 4           4        4  Rockabye (feat. Sean Paul & Anne-Marie)
# 5           5        5                                One Dance
#
#              Artist    Streams  \
# 1        The Weeknd  3135625.0
# 2  The Chainsmokers  3015525.0
# 3          DJ Snake  2545384.0
# 4      Clean Bandit  2356604.0
# 5             Drake  2259887.0
#
#                                                      URL        Date
# 1  https://open.spotify.com/track/5aAx2yezTd8zXrkmtKl66Z  2017-01-01
# 2  https://open.spotify.com/track/7BKLCZ1jbUBVqRi2FVlTVw  2017-01-01
# 3  https://open.spotify.com/track/4pdPtRcBmOSQDlJ3Fk945m  2017-01-01
# 4  https://open.spotify.com/track/5knuzwU65gJK7IF5yJsuaW  2017-01-01
# 5  https://open.spotify.com/track/1xznGGDReH1oQq0xzbwXa3  2017-01-01

# %%
unique_artists = df['Artist'].drop_duplicates().to_frame()

# %%
unique_artists.head()
# Out:
#              Artist
# 1        The Weeknd
# 2  The Chainsmokers
# 3          DJ Snake
# 4      Clean Bandit
# 5             Drake

# %%
unique_artists['api_artist'] = ""

# %%
unique_artists['api_url'] = ""

# %%
unique_artists = unique_artists.reset_index()
unique_artists = unique_artists.drop('index', axis=1)
unique_artists.head()
# Out:
#              Artist api_artist api_url
# 0        The Weeknd
# 1  The Chainsmokers
# 2          DJ Snake
# 3      Clean Bandit
# 4             Drake

# %%
for x in range(len(unique_artists)):
    placeholder = spotify.search(unique_artists.iloc[x][0])
    if len(placeholder['tracks']['items']) != 0:
        try:
            for counter in range(len(placeholder['tracks']['items'])):
                if unique_artists.iloc[x][0] == placeholder['tracks']['items'][counter]['album']['artists'][0]['name']:
                    unique_artists.at[x,'api_artist'] = placeholder['tracks']['items'][counter]['album']['artists'][0]['name']
                    unique_artists.at[x,'api_url'] = placeholder['tracks']['items'][counter]['album']['artists'][0]['external_urls']['spotify']
        except:
            print (placeholder)

# %%
unique_artists.head()
# Out:
#              Artist        api_artist  \
# 0        The Weeknd        The Weeknd
# 1  The Chainsmokers  The Chainsmokers
# 2          DJ Snake          DJ Snake
# 3      Clean Bandit      Clean Bandit
# 4             Drake             Drake
#
#                                                   api_url
# 0  https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ
# 1  https://open.spotify.com/artist/69GGBxA162lTqCwzJG5jLp
# 2  https://open.spotify.com/artist/540vIaP2JwjQb9dm3aArA4
# 3  https://open.spotify.com/artist/6MDME20pz9RveH9rEXvrOM
# 4  https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4

# %%
unique_artists[unique_artists['Artist'] != unique_artists['api_artist']].head()
# Out:
#               Artist api_artist api_url
# 166  La La Land Cast
# 175         Anuel Aa
# 180       Emma Stone
# 184             Grey
# 187           Amin̩

# %%
unique_artists['artist_api_id'] = unique_artists['api_url'].str[32:1000]
unique_artists['genres'] = np.NaN
unique_artists['genres'].astype('object')
unique_artists.head()
# Out:
#              Artist        api_artist  \
# 0        The Weeknd        The Weeknd
# 1  The Chainsmokers  The Chainsmokers
# 2          DJ Snake          DJ Snake
# 3      Clean Bandit      Clean Bandit
# 4             Drake             Drake
#
#                                                   api_url  \
# 0  https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ
# 1  https://open.spotify.com/artist/69GGBxA162lTqCwzJG5jLp
# 2  https://open.spotify.com/artist/540vIaP2JwjQb9dm3aArA4
# 3  https://open.spotify.com/artist/6MDME20pz9RveH9rEXvrOM
# 4  https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4
#
#             artist_api_id  genres
# 0  1Xyo4u8uXC1ZmMpatF05PJ     NaN
# 1  69GGBxA162lTqCwzJG5jLp     NaN
# 2  540vIaP2JwjQb9dm3aArA4     NaN
# 3  6MDME20pz9RveH9rEXvrOM     NaN
# 4  3TVXtAsR1Inumwj472S9r4     NaN

# %%
unique_artists.shape
# Out:
# (736, 5)

# %%
genre_df = unique_artists
genre_df.head()
# Out:
#              Artist        api_artist  \
# 0        The Weeknd        The Weeknd
# 1  The Chainsmokers  The Chainsmokers
# 2          DJ Snake          DJ Snake
# 3      Clean Bandit      Clean Bandit
# 4             Drake             Drake
#
#                                                   api_url  \
# 0  https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ
# 1  https://open.spotify.com/artist/69GGBxA162lTqCwzJG5jLp
# 2  https://open.spotify.com/artist/540vIaP2JwjQb9dm3aArA4
# 3  https://open.spotify.com/artist/6MDME20pz9RveH9rEXvrOM
# 4  https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4
#
#             artist_api_id  genres
# 0  1Xyo4u8uXC1ZmMpatF05PJ     NaN
# 1  69GGBxA162lTqCwzJG5jLp     NaN
# 2  540vIaP2JwjQb9dm3aArA4     NaN
# 3  6MDME20pz9RveH9rEXvrOM     NaN
# 4  3TVXtAsR1Inumwj472S9r4     NaN

# %%
genre_df.shape
# Out:
# (736, 5)

# %%
genre_df[genre_df['api_url'] == ''].head()
# Out:
#               Artist api_artist api_url artist_api_id  genres
# 166  La La Land Cast                                      NaN
# 175         Anuel Aa                                      NaN
# 180       Emma Stone                                      NaN
# 184             Grey                                      NaN
# 187           Amin̩                                      NaN

# %%
spotify.artist(genre_df.iloc[1]['artist_api_id'])
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/69GGBxA162lTqCwzJG5jLp'},
#  'followers': {'href': None, 'total': 13026129},
#  'genres': ['edm', 'electropop', 'pop', 'tropical house'],
#  'href': 'https://api.spotify.com/v1/artists/69GGBxA162lTqCwzJG5jLp',
#  'id': '69GGBxA162lTqCwzJG5jLp',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/960547a625bc2eb742bb3dd170cbc049d2e94cf9',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/9da714082fe9696529abadc8e4095451221b4483',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/caca64268346846a0753ca894b6ff92bb4dfb864',
#    'width': 160}],
#  'name': 'The Chainsmokers',
#  'popularity': 90,
#  'type': 'artist',
#  'uri': 'spotify:artist:69GGBxA162lTqCwzJG5jLp'}

# %%
genre_df['artist_api_id'].head()
# Out:
# 0    1Xyo4u8uXC1ZmMpatF05PJ
# 1    69GGBxA162lTqCwzJG5jLp
# 2    540vIaP2JwjQb9dm3aArA4
# 3    6MDME20pz9RveH9rEXvrOM
# 4    3TVXtAsR1Inumwj472S9r4
# Name: artist_api_id, dtype: object

# %%
unique_artists['genres'] = unique_artists['genres'].astype('object')

# %%
for x in range(1):
    placeholder = spotify.artist(genre_df.iloc[x]['artist_api_id'])
    try:
        genre_df.at[x,'genres'] = placeholder['genres']
    except:
        genre_df.at[x,'genres'] = 'error'

# %%
genre_df.head()
# Out:
#              Artist        api_artist  \
# 0        The Weeknd        The Weeknd
# 1  The Chainsmokers  The Chainsmokers
# 2          DJ Snake          DJ Snake
# 3      Clean Bandit      Clean Bandit
# 4             Drake             Drake
#
#                                                   api_url  \
# 0  https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ
# 1  https://open.spotify.com/artist/69GGBxA162lTqCwzJG5jLp
# 2  https://open.spotify.com/artist/540vIaP2JwjQb9dm3aArA4
# 3  https://open.spotify.com/artist/6MDME20pz9RveH9rEXvrOM
# 4  https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4
#
#             artist_api_id  \
# 0  1Xyo4u8uXC1ZmMpatF05PJ
# 1  69GGBxA162lTqCwzJG5jLp
# 2  540vIaP2JwjQb9dm3aArA4
# 3  6MDME20pz9RveH9rEXvrOM
# 4  3TVXtAsR1Inumwj472S9r4
#
#                                                          genres
# 0  [canadian contemporary r&b, canadian pop, hip hop, pop, rap]
# 1                                                           NaN
# 2                                                           NaN
# 3                                                           NaN
# 4                                                           NaN

# %%
for x in range(len(genre_df)):
    if genre_df.iloc[x]['artist_api_id'] != '':
        placeholder = spotify.artist(genre_df.iloc[x]['artist_api_id'])
        try:
            genre_df.at[x,'genres'] = placeholder['genres']
        except:
            genre_df.at[x,'genres'] = 'error'

# %%
genre_df[genre_df['genres']=='error'].head()
# Out:
# Empty DataFrame
# Columns: [Artist, api_artist, api_url, artist_api_id, genres]
# Index: []

# %%
genre_df[genre_df['genres'].str.len() == 0].head()
# Out:
#              Artist      api_artist  \
# 37           Nevada          Nevada
# 55   Zay Hilfigerrr  Zay Hilfigerrr
# 135       MiC LOWRY       MiC LOWRY
# 164          Stanaj          Stanaj
# 218         Stormzy         Stormzy
#
#                                                     api_url  \
# 37   https://open.spotify.com/artist/15NtJjjHRFybdNSMyM9smT
# 55   https://open.spotify.com/artist/7nKeLE1toRtW4M279iS26h
# 135  https://open.spotify.com/artist/0AJUYWKztkg5dnrHDIBv47
# 164  https://open.spotify.com/artist/3zrUX1hQrUB9aXcOiyQLmN
# 218  https://open.spotify.com/artist/2SrSdSvpminqmStGELCSNd
#
#               artist_api_id genres
# 37   15NtJjjHRFybdNSMyM9smT     []
# 55   7nKeLE1toRtW4M279iS26h     []
# 135  0AJUYWKztkg5dnrHDIBv47     []
# 164  3zrUX1hQrUB9aXcOiyQLmN     []
# 218  2SrSdSvpminqmStGELCSNd     []

# %%
genre_df.head()
# Out:
#              Artist        api_artist  \
# 0        The Weeknd        The Weeknd
# 1  The Chainsmokers  The Chainsmokers
# 2          DJ Snake          DJ Snake
# 3      Clean Bandit      Clean Bandit
# 4             Drake             Drake
#
#                                                   api_url  \
# 0  https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ
# 1  https://open.spotify.com/artist/69GGBxA162lTqCwzJG5jLp
# 2  https://open.spotify.com/artist/540vIaP2JwjQb9dm3aArA4
# 3  https://open.spotify.com/artist/6MDME20pz9RveH9rEXvrOM
# 4  https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4
#
#             artist_api_id  \
# 0  1Xyo4u8uXC1ZmMpatF05PJ
# 1  69GGBxA162lTqCwzJG5jLp
# 2  540vIaP2JwjQb9dm3aArA4
# 3  6MDME20pz9RveH9rEXvrOM
# 4  3TVXtAsR1Inumwj472S9r4
#
#                                                                      genres
# 0              [canadian contemporary r&b, canadian pop, hip hop, pop, rap]
# 1                                    [edm, electropop, pop, tropical house]
# 2                    [dance pop, edm, electronic trap, pop, tropical house]
# 3  [dance pop, edm, pop, post-teen pop, tropical house, uk dance, uk funky]
# 4      [canadian hip hop, canadian pop, hip hop, pop rap, rap, toronto rap]

# %%
len(genre_df.iloc[706]['genres'])
# Out:
# 1

# %%
genre_df.iloc[706]['genres']
# Out:
# ['k-pop']

# %%
genre_df.head()
# Out:
#              Artist        api_artist  \
# 0        The Weeknd        The Weeknd
# 1  The Chainsmokers  The Chainsmokers
# 2          DJ Snake          DJ Snake
# 3      Clean Bandit      Clean Bandit
# 4             Drake             Drake
#
#                                                   api_url  \
# 0  https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ
# 1  https://open.spotify.com/artist/69GGBxA162lTqCwzJG5jLp
# 2  https://open.spotify.com/artist/540vIaP2JwjQb9dm3aArA4
# 3  https://open.spotify.com/artist/6MDME20pz9RveH9rEXvrOM
# 4  https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4
#
#             artist_api_id  \
# 0  1Xyo4u8uXC1ZmMpatF05PJ
# 1  69GGBxA162lTqCwzJG5jLp
# 2  540vIaP2JwjQb9dm3aArA4
# 3  6MDME20pz9RveH9rEXvrOM
# 4  3TVXtAsR1Inumwj472S9r4
#
#                                                                      genres
# 0              [canadian contemporary r&b, canadian pop, hip hop, pop, rap]
# 1                                    [edm, electropop, pop, tropical house]
# 2                    [dance pop, edm, electronic trap, pop, tropical house]
# 3  [dance pop, edm, pop, post-teen pop, tropical house, uk dance, uk funky]
# 4      [canadian hip hop, canadian pop, hip hop, pop rap, rap, toronto rap]

# %%
unique_genres = genre_df['genres'].reset_index()

# %%
print(unique_genres.iloc[706])
# Out:
# index         706
# genres    [k-pop]
# Name: 706, dtype: object

# %%
print (type(unique_genres.iloc[706]))
# Out:
# <class 'pandas.core.series.Series'>

# %%
len(unique_genres)
# Out:
# 736

# %%
np.isnan(unique_genres.iloc[706]['genres'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-96ba7bf7932f> in <module>
# ----> 1 np.isnan(unique_genres.iloc[706]['genres'])
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
type(unique_genres.iloc[44]['genres'])
# Out:
# list

# %%
placeholder_list = []
for x in range(len(unique_genres)):
    if type(unique_genres.iloc[x]['genres']) != float:
        print (x)
        placeholder_list.extend(unique_genres.iloc[x]['genres'])
        print (unique_genres.iloc[x]['genres'])
# Out:
# 0
# ['canadian contemporary r&b', 'canadian pop', 'hip hop', 'pop', 'rap']
# 1
# ['edm', 'electropop', 'pop', 'tropical house']
# 2
# ['dance pop', 'edm', 'electronic trap', 'pop', 'tropical house']
# 3
# ['dance pop', 'edm', 'pop', 'post-teen pop', 'tropical house', 'uk dance', 'uk funky']
# 4
# ['canadian hip hop', 'canadian pop', 'hip hop', 'pop rap', 'rap', 'toronto rap']
# 5
# ['pop', 'post-teen pop']
# 6
# ['pop']
# 7
# ['hip hop', 'pop', 'pop rap', 'rap', 'southern hip hop', 'trap music']
# 8
# ['colombian pop', 'dance pop', 'latin', 'latin pop', 'mexican pop', 'pop']
# 9
# ['dance pop', 'pop', 'post-teen pop']
# 10
# ['dance pop', 'pop', 'post-teen pop', 'talent show']
# 11
# ['atl hip hop', 'pop', 'pop rap', 'rap', 'southern hip hop', 'trap music']
# 12
# ['dance pop', 'edm', 'electro house', 'moombahton', 'pop', 'pop rap', 'tropical house']
# 13
# ['big room', 'edm', 'pop', 'progressive house', 'tropical house']
# 14
# ['dance pop', 'pop', 'post-teen pop']
# 15
# ['aussietronica']
# 16
# ['dance pop', 'pop']
# 17
# ['canadian pop', 'dance pop', 'pop', 'viral pop']
# 18
# ['big room', 'dance pop', 'edm', 'electro house', 'pop', 'tropical house']
# 19
# ['edm', 'electro house', 'house', 'pop', 'progressive house', 'uk dance']
# 20
# ['dance pop', 'pop', 'post-teen pop', 'tropical house']
# 21
# ['hip hop', 'pop rap', 'rap']
# 22
# ['pop punk', 'rock']
# 23
# ['australian dance', 'australian pop', 'pop']
# 24
# ['boy band', 'latin', 'latin pop', 'pop', 'reggaeton', 'tropical']
# 25
# ['pop rap', 'rap', 'trap music']
# 26
# ['dance pop', 'pop', 'pop rap']
# 27
# ['latin', 'reggaeton']
# 28
# ['dance pop', 'girl group', 'pop', 'pop rap', 'post-teen pop', 'r&b', 'talent show']
# 29
# ['canadian contemporary r&b', 'dance pop', 'pop', 'post-teen pop', 'r&b']
# 30
# ['dance pop', 'latin', 'latin pop', 'mexican pop', 'tropical']
# 31
# ['australian pop', 'boy band', 'dance pop', 'pop', 'post-teen pop', 'tropical house']
# 32
# ['dance pop', 'edm', 'pop', 'tropical house', 'uk dance']
# 33
# ['dance pop', 'pop', 'post-teen pop', 'viral pop']
# 34
# ['hip hop', 'pop', 'pop rap', 'portland hip hop', 'rap']
# 35
# ['dance pop', 'hyphy', 'pop', 'pop rap', 'r&b', 'rap', 'southern hip hop', 'trap music', 'west coast trap']
# 36
# ['neo mellow', 'neo soul', 'pop', 'r&b', 'urban contemporary']
# 37
# []
# 38
# ['electro house']
# 39
# ['dance pop', 'pop', 'post-teen pop', 'r&b', 'urban contemporary']
# 40
# ['latin', 'latin hip hop', 'latin pop', 'pop', 'reggaeton', 'tropical']
# 41
# ['dance pop', 'edm', 'electropop', 'pop', 'post-teen pop', 'scandipop', 'swedish electropop', 'swedish pop', 'tropical house']
# 42
# ['brazilian edm', 'electro house', 'pop nacional']
# 43
# ['dance pop', 'deep euro house', 'deep house', 'edm', 'german dance', 'pop', 'tropical house']
# 44
# ['detroit hip hop', 'hip hop', 'pop', 'pop rap', 'r&b', 'rap', 'southern hip hop', 'trap music']
# 45
# ['canadian pop', 'dance pop', 'pop', 'post-teen pop']
# 46
# ['dance pop', 'pop', 'post-teen pop']
# 47
# ['champeta', 'colombian pop', 'latin', 'latin pop', 'tropical', 'vallenato']
# 48
# ['hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap music', 'viral trap']
# 49
# ['dance pop', 'electropop', 'pop', 'scandipop', 'tropical house']
# 50
# ['conscious hip hop', 'nc hip hop', 'pop rap', 'rap']
# 51
# ['latin', 'latin hip hop', 'pop', 'reggaeton', 'tropical']
# 52
# ['colombian pop']
# 53
# ['atl hip hop', 'rap', 'trap music']
# 54
# ['british soul', 'pop', 'uk pop']
# 55
# []
# 56
# ['dance pop', 'latin', 'latin pop', 'mexican pop', 'pop', 'tropical']
# 57
# ['permanent wave', 'pop']
# 58
# ['dance pop', 'pop', 'post-teen pop']
# 59
# ['hip hop', 'new orleans rap', 'pop', 'pop rap', 'rap', 'trap music']
# 60
# ['big room', 'dance pop', 'danish electronic', 'edm', 'electro house', 'pop', 'pop edm', 'tropical house', 'uk dance']
# 61
# ['san diego rap', 'underground hip hop']
# 62
# ['brega funk', 'funk carioca', 'funk das antigas', 'funk ostentacao']
# 63
# ['dance pop', 'deep tropical house', 'edm', 'electro house', 'pop', 'pop edm', 'swedish tropical house', 'tropical house']
# 64
# ['neo soul']
# 65
# ['danish pop', 'pop', 'scandipop']
# 66
# ['deep tropical house', 'edm', 'tropical house']
# 67
# ['lgbtq+ hip hop', 'nyc rap', 'rap', 'trap music']
# 68
# ['dance pop', 'downtempo', 'electropop', 'pop', 'post-teen pop', 'shiver pop']
# 69
# ['dance pop', 'pop', 'post-teen pop']
# 70
# ['indie pop rap', 'indie r&b', 'pop', 'pop rap']
# 71
# ['chicago rap', 'conscious hip hop', 'hip hop', 'pop rap', 'rap']
# 72
# ['dance pop', 'girl group', 'pop', 'post-teen pop', 'r&b', 'talent show', 'uk pop']
# 73
# ['reggaeton', 'trap latino']
# 74
# ['hip hop', 'indie pop rap', 'pop', 'pop rap', 'rap']
# 75
# ['electropop', 'indie electro-pop', 'indie poptimism', 'la pop', 'modern rock', 'pop', 'pop edm', 'tropical house']
# 76
# ['pop']
# 77
# ['cubaton', 'reggaeton']
# 78
# ['reggaeton']
# 79
# ['dance pop', 'electro latino', 'latin', 'latin hip hop', 'latin pop', 'pop', 'pop reggaeton', 'reggaeton', 'tropical']
# 80
# ['new french touch', 'tropical house']
# 81
# ['dance pop', 'edm', 'electro house', 'electropop', 'pop', 'pop edm', 'post-teen pop', 'tropical house']
# 82
# ['dance pop', 'danish pop', 'electropop', 'pop', 'tropical house']
# 83
# ['pop', 'pop rap']
# 84
# ['neo mellow', 'pop', 'pop rock', 'post-teen pop', 'viral pop']
# 85
# ['dance pop', 'latin', 'latin hip hop', 'latin pop', 'pop', 'reggaeton', 'reggaeton flow', 'tropical']
# 86
# ['glam rock', 'rock']
# 87
# ['atl hip hop', 'atl trap', 'gangster rap', 'pop', 'pop rap', 'rap', 'trap music']
# 88
# ['philly rap', 'rap', 'trap music']
# 89
# ['chicano rap']
# 90
# ['pop', 'uk pop']
# 91
# ['indie pop', 'indie rock', 'modern rock', 'pop', 'rock']
# 92
# ['atl hip hop', 'hip hop', 'pop', 'pop rap', 'rap']
# 93
# ['big room', 'dance pop', 'edm', 'electro house', 'pop', 'tropical house']
# 94
# ['dance pop', 'pop', 'pop rap']
# 95
# ['australian pop', 'dance pop', 'neo mellow', 'pop', 'post-teen pop']
# 96
# ['australian dance', 'australian electropop', 'australian indie', 'downtempo', 'pop']
# 97
# ['dance pop', 'pop', 'post-teen pop']
# 98
# ['dance pop', 'edm', 'pop']
# 99
# ['dance pop', 'pop', 'pop rap']
# 100
# ['colombian pop', 'latin']
# 101
# ['indie cafe pop', 'post-teen pop', 'viral pop']
# 102
# ['motown']
# 103
# ['modern rock', 'pop']
# 104
# ['australian pop', 'pop']
# 105
# ['pop', 'pop rap', 'rap']
# 106
# ['edm', 'progressive electro house', 'swedish pop']
# 107
# ['classic soul', 'funk', 'motown', 'northern soul', 'quiet storm', 'soul']
# 108
# ['dance pop', 'electropop', 'indie poptimism', 'pop', 'post-teen pop']
# 109
# ['atl hip hop', 'hip hop', 'pop', 'pop rap', 'rap', 'southern hip hop', 'trap music']
# 110
# ['dancehall', 'soca']
# 111
# ['latin', 'latin hip hop', 'pop', 'reggaeton', 'tropical']
# 112
# ['dance pop', 'latin', 'latin pop', 'mexican pop', 'pop', 'tropical']
# 113
# ['dance pop', 'edm', 'miami hip hop', 'pop', 'pop rap']
# 114
# ['deep big room', 'deep tropical house', 'electro house', 'pop edm']
# 115
# ['dance pop', 'pop', 'post-teen pop', 'tropical house']
# 116
# ['cubaton', 'dance pop', 'latin', 'latin hip hop', 'latin pop', 'pop', 'reggaeton', 'tropical']
# 117
# ['pop', 'pop rap', 'rap']
# 118
# ['bass trap', 'edm', 'electro house', 'electronic trap', 'pop', 'pop edm', 'tropical house', 'vapor twitch']
# 119
# ['latin', 'reggaeton', 'trap latino', 'tropical']
# 120
# ['deep tropical house', 'pop edm', 'swedish tropical house', 'tropical house']
# 121
# ['australian pop']
# 122
# ['dance pop', 'pop', 'post-teen pop', 'tropical house', 'uk pop']
# 123
# ['dance pop', 'indie poptimism', 'indie r&b', 'pop', 'pop rap', 'post-teen pop', 'r&b', 'rap']
# 124
# ['dance pop', 'dancehall']
# 125
# ['edm', 'pop', 'tropical house']
# 126
# ['brostep', 'complextro', 'edm', 'electro']
# 127
# ['dance pop', 'electropop', 'indie poptimism', 'metropopolis', 'pop', 'post-teen pop', 'r&b', 'swedish electropop', 'swedish pop', 'swedish synthpop', 'tropical house']
# 128
# ['tropical house']
# 129
# ['detroit hip hop', 'g funk', 'hip hop', 'rap']
# 130
# ['dance pop', 'escape room', 'new rave', 'pop']
# 131
# ['australian pop', 'neo mellow', 'pop', 'pop rock']
# 132
# ['chicago rap', 'hip hop', 'pop rap', 'rap']
# 133
# ['dance pop', 'edm', 'electro house', 'house', 'pop', 'pop edm', 'tropical house', 'uk dance']
# 134
# ['dfw rap', 'pop', 'rap']
# 135
# []
# 136
# ['motown', 'quiet storm', 'soul']
# 137
# ['east coast hip hop', 'gangster rap', 'hip hop', 'pop rap', 'rap', 'southern hip hop']
# 138
# ['australian pop', 'dance pop', 'neo mellow', 'pop', 'r&b', 'tropical house', 'uk pop']
# 139
# ['big room', 'canadian electronic', 'dance pop', 'deep big room', 'edm', 'electro house', 'pop', 'tropical house']
# 140
# ['dance pop', 'pop']
# 141
# ['german pop']
# 142
# ['neo mellow', 'pop']
# 143
# ['pop', 'post-teen pop']
# 144
# ['channel islands indie', 'vapor soul']
# 145
# ['dance pop', 'pop', 'post-teen pop']
# 146
# ['indie rock', 'modern rock', 'permanent wave', 'rock']
# 147
# ['hip hop', 'pop', 'pop rap', 'r&b', 'rap', 'trap music']
# 148
# ['folk-pop', 'irish singer-songwriter', 'pop']
# 149
# ['australian pop']
# 150
# ['brooklyn indie', 'dance pop', 'electropop', 'indie electro-pop', 'indie poptimism', 'indietronica', 'metropopolis', 'nyc pop', 'pop', 'vapor pop', 'vapor soul']
# 151
# ['dance pop', 'pop', 'pop rap', 'r&b', 'rap']
# 152
# ['dance pop', 'edm', 'electropop', 'pop', 'tropical house']
# 153
# ['downtempo', 'dream pop', 'indietronica', 'pop']
# 154
# ['pop', 'pop rap', 'rap', 'trap music']
# 155
# ['metropopolis', 'nottingham indie', 'pop', 'tropical house']
# 156
# ['dance pop', 'edm', 'liquid funk', 'pop', 'tropical house', 'uk funky']
# 157
# ['latin', 'latin hip hop', 'reggaeton', 'tropical']
# 158
# ['dance pop', 'edm', 'house', 'pop', 'tropical house', 'uk dance']
# 159
# ['edm', 'electropop', 'indie poptimism', 'pop', 'pop edm', 'tropical house']
# 160
# ['dance pop', 'electropop', 'etherpop', 'indie poptimism', 'pop', 'post-teen pop']
# 161
# ['big room', 'brostep', 'dance pop', 'edm', 'electro house', 'house', 'pop', 'trance', 'tropical house']
# 162
# ['latin', 'latin pop', 'pop', 'tropical']
# 163
# ['dance pop', 'pop', 'post-teen pop', 'viral pop']
# 164
# []
# 165
# ['dance pop', 'pop', 'post-teen pop']
# 167
# ['hollywood']
# 168
# ['dance pop', 'pop', 'post-teen pop']
# 169
# ['pop', 'pop rap', 'rap', 'southern hip hop', 'trap music']
# 170
# ['atl hip hop', 'dirty south rap', 'hip hop', 'pop', 'pop rap', 'rap', 'southern hip hop', 'trap music']
# 171
# ['britpop', 'madchester', 'permanent wave', 'rock']
# 172
# ['neo mellow', 'pop', 'pop rock', 'singer-songwriter']
# 173
# ['rap', 'southern hip hop', 'trap music', 'underground hip hop', 'vapor trap']
# 174
# ['modern rock', 'rock']
# 176
# ['hip hop', 'pop', 'pop rap', 'r&b', 'rap', 'toronto rap', 'trap music', 'urban contemporary']
# 177
# ['neo mellow', 'pop', 'pop rock']
# 178
# ['latin', 'latin hip hop', 'reggaeton', 'reggaeton flow', 'tropical']
# 179
# ['dance pop', 'pop', 'r&b']
# 181
# ['hollywood', 'movie tunes']
# 182
# ['florida rap', 'miami hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap music']
# 183
# ['pop']
# 185
# ['big room', 'deep big room', 'deep tropical house', 'edm', 'electro house', 'funky tech house', 'german techno', 'pop edm', 'progressive electro house', 'progressive house', 'sky room']
# 186
# ['contemporary country', 'country pop']
# 188
# ['big room', 'dance pop', 'edm', 'electro house', 'pop', 'progressive electro house', 'tropical house']
# 190
# ['dance pop', 'post-teen pop']
# 191
# ['icelandic indie', 'modern alternative rock', 'modern rock']
# 193
# ['album rock', 'classic rock', 'hard rock', 'mellow gold', 'rock', 'soft rock']
# 194
# ['dance pop', 'pop', 'post-teen pop']
# 195
# ['big room', 'dance pop', 'edm', 'electro house', 'pop', 'tropical house']
# 196
# ['dance pop', 'pop', 'post-teen pop', 'r&b', 'viral pop']
# 197
# ['dance pop', 'electropop', 'norwegian pop', 'pop', 'tropical house']
# 198
# ['dance pop', 'pop', 'post-teen pop', 'uk pop']
# 199
# ['emo rap', 'miami hip hop']
# 200
# ['electro house']
# 201
# ['dance pop', 'pop', 'post-teen pop', 'viral pop']
# 202
# ['k-pop', 'k-pop boy group']
# 203
# ['electropop']
# 204
# ['dance pop', 'edm', 'electropop', 'metropopolis', 'pop', 'post-teen pop', 'r&b', 'tropical house']
# 205
# ['swedish pop', 'tropical house']
# 206
# ['dance pop', 'neo mellow', 'pop', 'pop rock', 'post-teen pop', 'viral pop']
# 207
# ['alternative rock', 'neo mellow', 'permanent wave', 'pop rock', 'post-grunge', 'rock']
# 208
# ['irish rock', 'modern rock', 'neo mellow', 'permanent wave', 'pop rock', 'rock']
# 209
# ['chamber pop', 'eau claire indie', 'folk-pop', 'indie folk', 'indie pop', 'melancholia', 'slow core', 'stomp and holler']
# 210
# ['hip hop', 'miami hip hop', 'pop', 'pop rap', 'rap', 'southern hip hop', 'trap music']
# 211
# ['alternative metal', 'nu metal', 'post-grunge', 'rap metal']
# 212
# ['canadian hip hop', 'pop', 'pop rap', 'rap', 'southern hip hop', 'toronto rap', 'trap music']
# 213
# ['latin', 'pop', 'reggaeton', 'tropical']
# 214
# ['dance pop', 'electropop', 'pop']
# 215
# ['alternative dance', 'australian dance', 'filter house', 'indietronica', 'new rave', 'nu disco']
# 216
# ['complextro', 'dance pop', 'edm', 'electro house', 'german techno', 'pop', 'post-teen pop', 'tropical house']
# 217
# ['dance pop', 'pop', 'pop rap', 'post-teen pop', 'r&b']
# 218
# []
# 219
# ['funk carioca', 'funk ostentacao']
# 220
# ['champeta', 'colombian pop', 'electro latino', 'latin', 'latin pop', 'pop', 'tropical']
# 221
# ['trap music']
# 222
# ['dance pop', 'indie poptimism', 'pop', 'post-teen pop', 'viral pop']
# 223
# ['latin', 'latin arena pop', 'latin pop', 'mexican pop', 'ranchera', 'tropical']
# 224
# ['pop', 'rap']
# 225
# ['art pop', 'dance pop', 'electropop', 'metropopolis', 'nz pop', 'pop', 'r&b']
# 226
# ['dance pop', 'edm', 'electro house', 'indie poptimism', 'pop', 'pop edm', 'tropical house']
# 227
# ['dance pop', 'hip pop', 'pop', 'pop rap', 'post-teen pop', 'r&b', 'rap']
# 228
# ['norwegian pop']
# 229
# ['dance pop', 'electropop', 'norwegian pop', 'pop', 'post-teen pop', 'tropical house']
# 230
# ['dance pop', 'latin', 'miami hip hop', 'pop', 'pop rap']
# 231
# ['alternative r&b', 'hip hop', 'lgbtq+ hip hop', 'pop', 'pop rap', 'r&b', 'rap']
# 232
# ['europop', 'swedish idol pop', 'swedish pop']
# 233
# ['europop', 'eurovision', 'swedish idol pop', 'swedish pop']
# 234
# []
# 235
# ['classic rock', 'rock', 'rock-and-roll', 'rockabilly', 'soul']
# 236
# ['dutch hip hop']
# 237
# ['conscious hip hop', 'hip hop', 'pop rap', 'rap', 'west coast rap']
# 238
# ['alternative hip hop', 'art pop']
# 239
# ['australian hip hop', 'dance pop', 'hip pop', 'pop', 'pop rap', 'post-teen pop', 'r&b']
# 240
# ['bachata', 'latin', 'latin pop', 'pop', 'tropical']
# 241
# ['conscious hip hop', 'dmv rap', 'hip hop', 'pop rap', 'rap']
# 242
# ['indie rock']
# 243
# ['afro dancehall', 'afropop', 'azonto', 'nigerian hip hop', 'nigerian pop']
# 244
# ['dance pop', 'indie cafe pop', 'pop', 'post-teen pop', 'viral pop']
# 245
# ['dance pop', 'pop', 'post-teen pop']
# 246
# ['conscious hip hop', 'gangster rap', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap music', 'underground hip hop']
# 247
# ['latin', 'latin hip hop', 'reggaeton flow', 'trap latino', 'tropical']
# 248
# ['pop']
# 249
# ['hip hop', 'pop', 'pop rap', 'rap', 'southern hip hop', 'trap music']
# 250
# ['folk-pop', 'indie folk', 'indie pop', 'new americana', 'stomp and holler']
# 251
# ['rap', 'trap music']
# 252
# ['atl hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap music', 'underground hip hop']
# 253
# ['candy pop', 'emo', 'pixie', 'pop emo', 'pop punk']
# 254
# ['atl hip hop', 'hip hop', 'pop', 'pop rap', 'rap', 'trap music', 'underground hip hop']
# 255
# ['dance pop', 'piano rock', 'pop', 'pop rap', 'pop rock', 'post-teen pop']
# 256
# ['emo', 'modern rock', 'pop punk']
# 257
# ['alternative dance', 'dance-punk', 'indie pop', 'indie rock', 'indietronica', 'modern rock', 'new rave']
# 258
# ['dance pop', 'folk-pop', 'indie pop', 'indietronica', 'metropopolis', 'modern rock', 'pop', 'tropical house']
# 259
# ['latin', 'latin pop', 'pop', 'tropical']
# 260
# ['album rock', 'art rock', 'bow pop', 'classic rock', 'folk rock', 'glam rock', 'mellow gold', 'rock', 'soft rock', 'symphonic rock']
# 261
# ['album rock', 'classic rock', 'mellow gold', 'rock', 'soft rock', 'yacht rock']
# 262
# ['dance pop', 'pop', 'post-teen pop']
# 263
# ['dance pop', 'edm', 'electro house', 'german dance', 'pop', 'tropical house']
# 264
# ['tropical house']
# 265
# ['eurovision', 'portuguese pop']
# 266
# ['eurovision']
# 268
# ['alternative metal', 'alternative rock', 'grunge', 'hard rock', 'modern rock', 'nu metal', 'post-grunge', 'rock']
# 269
# ['alternative metal', 'alternative rock', 'hard rock', 'modern rock', 'nu metal', 'permanent wave', 'post-grunge', 'rock']
# 270
# ['alternative metal', 'alternative rock', 'grunge', 'post-grunge', 'rock']
# 271
# ['dance pop', 'edm', 'pop', 'post-teen pop', 'tropical house']
# 272
# ['dance pop', 'pop', 'post-teen pop']
# 273
# ['modern rock', 'permanent wave', 'piano rock', 'post-grunge', 'rock']
# 274
# ['canadian pop']
# 275
# ['grime', 'uk hip hop']
# 276
# ['dance pop', 'edm', 'pop', 'post-teen pop', 'r&b', 'tropical house', 'uk pop']
# 277
# ['big room', 'dance pop', 'disco house', 'edm', 'electro house', 'filter house', 'house', 'pop', 'pop rap', 'tropical house', 'vocal house']
# 279
# ['atl hip hop', 'hip hop', 'pop', 'pop rap', 'rap', 'southern hip hop', 'trap music']
# 280
# ['baile pop', 'funk carioca', 'funk das antigas']
# 281
# ['colombian pop', 'latin', 'reggaeton']
# 282
# ['dance pop', 'pop', 'post-teen pop']
# 283
# ['hip hop', 'pop', 'pop rap', 'r&b', 'rap']
# 284
# ['dance pop', 'edm', 'pop', 'tropical house', 'uk dance']
# 285
# ['dance pop', 'europop', 'hands up', 'italo dance']
# 286
# ['pop rap']
# 287
# ['east coast hip hop', 'gangster rap', 'hardcore hip hop', 'hip hop', 'pop rap', 'rap']
# 288
# ['swedish pop']
# 289
# ['hip hop', 'pop', 'pop rap', 'rap', 'southern hip hop', 'trap music']
# 290
# ['indie pop', 'indie poptimism', 'indietronica', 'modern rock']
# 291
# ['hip hop', 'rap']
# 292
# ['contemporary country', 'country', 'country road', 'modern country rock']
# 293
# ['album rock', 'blues-rock', 'classic rock', 'country rock', 'hard rock', 'mellow gold', 'rock', 'southern rock']
# 294
# ['dance pop', 'electropop', 'pop', 'pop rap', 'post-teen pop', 'r&b']
# 295
# ['dance pop', 'pop', 'pop rap', 'post-teen pop', 'r&b', 'urban contemporary']
# 296
# ['trap espanol']
# 297
# ['la pop', 'pop']
# 298
# ['dance pop', 'pop', 'post-teen pop', 'r&b']
# 299
# ['indie pop', 'indie rock', 'modern rock']
# 300
# ['celtic rock', 'neo mellow', 'pop', 'pop rock', 'post-teen pop', 'viral pop']
# 301
# ['indie folk', 'modern rock', 'neo mellow', 'pop']
# 302
# ['baile pop', 'funk carioca', 'funk ostentacao']
# 303
# ['deep german hip hop', 'german hip hop', 'hamburg hip hop']
# 304
# ['k-pop', 'k-pop boy group']
# 306
# ['big room', 'dance pop', 'edm', 'electro house', 'electropop', 'electropowerpop', 'indie poptimism', 'pop', 'pop edm', 'tropical house']
# 307
# ['dance pop', 'pop', 'post-teen pop']
# 308
# ['bachata', 'latin', 'tropical']
# 309
# ['dirty south rap', 'gangster rap', 'hip hop', 'memphis hip hop', 'pop', 'pop rap', 'rap', 'southern hip hop', 'trap music']
# 310
# ['latin viral pop', 'pop', 'reggaeton']
# 311
# ['latin', 'latin pop', 'latin viral pop', 'mexican pop']
# 312
# ['candy pop', 'dance pop', 'electropop', 'metropopolis', 'pop', 'post-teen pop', 'r&b', 'tropical house']
# 313
# ['belgian dance', 'belgian edm', 'big room', 'dance pop', 'deep big room', 'edm', 'electro house', 'progressive electro house', 'tropical house']
# 314
# ['pop', 'rap']
# 315
# ['latin arena pop', 'latin pop', 'latin viral pop', 'spanish pop']
# 316
# ['baile pop', 'dance pop', 'funk carioca', 'pop', 'pop nacional']
# 317
# ['alternative r&b', 'atl hip hop', 'hip hop', 'pop', 'pop rap', 'rap', 'trap music']
# 318
# ['reggaeton']
# 319
# ['big room', 'edm', 'pop']
# 320
# ['dance pop', 'pop', 'post-teen pop']
# 321
# ['brostep', 'progressive electro house']
# 322
# ['hip hop', 'pittsburgh rap', 'pop', 'pop rap', 'rap', 'southern hip hop', 'trap music']
# 323
# []
# 324
# ['disco', 'europop', 'new wave pop', 'soft rock']
# 325
# ['modern rock', 'pop punk', 'post-grunge', 'rock']
# 326
# ['alternative metal', 'alternative rock', 'modern rock', 'permanent wave', 'post-grunge', 'rock']
# 327
# ['dance pop', 'pop', 'pop rap', 'r&b', 'rap', 'urban contemporary']
# 328
# ['hip hop', 'pop', 'pop rap', 'rap', 'southern hip hop', 'trap music', 'underground hip hop', 'vapor trap']
# 329
# ['reggaeton']
# 330
# ['cali rap', 'dfw rap', 'rap', 'trap music', 'underground hip hop', 'vapor trap']
# 331
# ['latin', 'latin hip hop', 'latin pop', 'pop', 'reggaeton', 'reggaeton flow', 'tropical']
# 332
# ['australian pop', 'dance pop', 'neo mellow', 'pop', 'pop rock', 'post-teen pop', 'r&b', 'talent show']
# 333
# ['irish rock', 'permanent wave', 'rock']
# 334
# ['emo rap', 'miami hip hop', 'trap music']
# 335
# ['latin', 'reggaeton', 'tropical']
# 336
# ['latin', 'latin hip hop', 'latin pop', 'panamanian pop', 'pop', 'pop reggaeton', 'reggaeton', 'tropical']
# 337
# ['electropop', 'indie poptimism', 'pop', 'swedish electropop', 'swedish pop', 'swedish synthpop', 'tropical house']
# 338
# ['latin', 'latin arena pop', 'latin pop', 'mexican pop', 'pop']
# 339
# ['hip hop', 'pop', 'pop rap', 'rap', 'southern hip hop', 'trap music', 'underground hip hop']
# 340
# ['disco', 'funk', 'jazz funk', 'motown', 'quiet storm', 'soul']
# 341
# ['big room', 'dutch house', 'edm', 'electro house', 'pop', 'progressive electro house', 'tropical house']
# 343
# ['french hip hop', 'trap francais']
# 344
# ['german hip hop']
# 345
# ['album rock', 'classic rock', 'folk rock', 'heartland rock', 'mellow gold', 'pop rock', 'rock', 'roots rock', 'singer-songwriter', 'soft rock']
# 346
# ['album rock', 'classic rock', 'folk rock', 'hard rock', 'heartland rock', 'mellow gold', 'pop rock', 'psychedelic rock', 'rock', 'roots rock', 'soft rock']
# 347
# ['hip hop', 'rap']
# 348
# ['contemporary country', 'country road']
# 349
# ['atl hip hop', 'pop', 'pop rap', 'rap', 'southern hip hop', 'trap music']
# 350
# []
# 351
# ['german hip hop']
# 352
# ['alternative rock', 'funk metal', 'permanent wave', 'post-grunge', 'rock']
# 353
# ['australian pop', 'dance pop', 'electropop', 'indie poptimism', 'pop', 'post-teen pop', 'tropical house']
# 354
# ['latin', 'latin hip hop', 'reggaeton', 'reggaeton flow', 'trap latino', 'tropical']
# 355
# ['hip hop', 'pop', 'pop rap', 'r&b', 'rap', 'trap music']
# 356
# ['disco', 'funk', 'post-disco', 'quiet storm']
# 357
# ['atl hip hop', 'pop', 'pop rap', 'rap', 'trap music']
# 358
# ['album rock', 'australian rock', 'hard rock', 'rock']
# 362
# []
# 363
# ['hip hop', 'pop rap', 'rap']
# 364
# ['reggaeton', 'trap latino']
# 365
# ['emo rap', 'underground hip hop']
# 366
# ['metropopolis', 'modern rock', 'pop', 'tropical house']
# 367
# ['chicago rap', 'drill', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap music', 'underground hip hop', 'vapor trap']
# 368
# ['dance pop', 'pop', 'r&b', 'urban contemporary']
# 369
# ['emo rap']
# 370
# ['emo rap', 'lgbtq+ hip hop']
# 371
# ['bmore', 'edm', 'moombahton', 'ninja', 'pop']
# 372
# ['dance pop', 'dance rock', 'disco', 'europop', 'motown', 'new romantic', 'new wave', 'new wave pop', 'soft rock']
# 373
# []
# 374
# ['alabama rap', 'rap', 'trap music', 'underground hip hop', 'vapor trap']
# 375
# ['acoustic pop', 'neo mellow', 'pop', 'pop rock']
# 376
# ['british soul', 'dance pop', 'neo soul', 'pop', 'r&b', 'tropical house', 'urban contemporary']
# 377
# ['adult standards', 'brill building pop', 'easy listening', 'lounge', 'nashville sound', 'rockabilly', 'vocal jazz']
# 378
# ['italian hip hop', 'italian underground hip hop', 'rap sardegna']
# 379
# ['adult standards', 'brill building pop', 'easy listening', 'lounge', 'mellow gold', 'operatic pop', 'vocal jazz']
# 382
# ['ballroom', 'easy listening', 'lounge']
# 383
# ['baile pop', 'funk carioca', 'funk ostentacao']
# 384
# ['adult standards', 'easy listening', 'lounge']
# 385
# ['album rock', 'art rock', 'classic rock', 'folk rock', 'mellow gold', 'psychedelic rock', 'rock']
# 387
# ['adult standards', 'big band', 'easy listening', 'lounge', 'vocal jazz']
# 388
# ['hip hop', 'pop', 'pop rap', 'rap', 'underground hip hop']
# 389
# ['celtic', 'celtic punk', 'celtic rock', 'folk punk', 'irish folk', 'punk']
# 390
# ['art rock', 'blues-rock', 'classic rock', 'mellow gold', 'soft rock']
# 391
# ['album rock', 'art rock', 'classic rock', 'folk rock', 'mellow gold', 'rock', 'soft rock']
# 392
# ['new wave pop', 'rock-and-roll', 'rockabilly']
# 393
# ['belgian hip hop', 'french hip hop', 'rap conscient', 'trap francais']
# 394
# ['adult standards', 'lounge', 'vocal jazz']
# 395
# ['adult standards', 'american folk revival']
# 396
# ['rock-and-roll', 'rockabilly']
# 397
# ['post-romantic era', 'ukrainian classical']
# 398
# ['adult standards', 'brill building pop', 'easy listening', 'lounge', 'vocal jazz']
# 399
# ['a cappella']
# 400
# ['adult standards', 'lounge', 'vocal jazz']
# 401
# ['adult standards', 'jazz trio']
# 402
# ['rap', 'trap music']
# 403
# ['dance pop', 'europop', 'pop', 'pop rap', 'post-teen pop']
# 404
# ['glam rock', 'mellow gold', 'piano rock', 'rock']
# 405
# ['album rock', 'classic rock', 'mellow gold', 'rock', 'soft rock', 'yacht rock']
# 406
# ['dance pop', 'hip pop', 'pop', 'post-teen pop', 'r&b']
# 407
# ['australian dance', 'australian pop', 'dance pop', 'electropop', 'eurodance', 'europop', 'new wave pop', 'pop', 'pop rock']
# 408
# ['funk carioca', 'funk ostentacao']
# 409
# []
# 410
# ['colombian pop', 'latin']
# 411
# ['hip hop', 'pop', 'pop rap', 'rap', 'southern hip hop', 'trap music']
# 412
# ['baroque pop', 'brill building pop', 'folk rock', 'psychedelic rock', 'rock', 'sunshine pop']
# 413
# ['brill building pop', 'bubblegum pop', 'classic girl group', 'motown', 'rock-and-roll']
# 414
# ['heartland rock', 'mellow gold', 'permanent wave', 'rock', 'singer-songwriter']
# 415
# ['boy band', 'dance pop', 'europop', 'pop']
# 417
# ['disco', 'europop']
# 418
# ['adult standards', 'hollywood', 'lounge', 'vocal jazz']
# 419
# ['australian pop', 'british soul', 'dance pop', 'europop', 'pop', 'post-teen pop', 'r&b', 'talent show', 'uk pop']
# 420
# ['australian pop', 'dance pop', 'europop', 'hip pop', 'pop', 'pop rock', 'post-teen pop', 'r&b']
# 422
# ['album rock', 'classic rock', 'folk rock', 'heartland rock', 'mellow gold', 'rock', 'soft rock', 'yacht rock']
# 423
# ['album rock', 'canadian pop', 'canadian singer-songwriter', 'classic canadian rock', 'heartland rock', 'mellow gold', 'rock', 'soft rock']
# 424
# ['album rock', 'blues-rock', 'glam rock', 'hard rock', 'rock']
# 425
# ['adult standards', 'easy listening', 'lounge', 'vocal jazz']
# 426
# ['brill building pop']
# 427
# ['dance pop', 'girl group', 'hip pop', 'pop', 'pop rap', 'r&b', 'urban contemporary']
# 428
# ['adult standards', 'cowboy western', 'nashville sound', 'traditional country', 'western swing']
# 429
# ['classic uk pop', 'glam rock']
# 430
# ['adult standards', 'easy listening', 'lounge', 'vocal jazz']
# 431
# ['new wave pop']
# 432
# ['album rock', 'art rock', 'classic rock', 'dance rock', 'folk', 'folk rock', 'folk-pop', 'lilith', 'mellow gold', 'new romantic', 'new wave', 'new wave pop', 'permanent wave', 'pop rock', 'rock', 'roots rock', 'soft rock']
# 433
# ['neo-singer-songwriter', 'pop']
# 434
# ['adult standards', 'folk', 'mellow gold', 'soft rock']
# 435
# ['adult standards', 'brill building pop', 'bubblegum pop', 'classic uk pop', 'mellow gold', 'merseybeat', 'new wave pop', 'rock-and-roll', 'rockabilly', 'soft rock']
# 437
# ['adult standards', 'big band', 'brill building pop', 'deep adult standards', 'easy listening', 'lounge', 'swing', 'vocal jazz']
# 438
# ['adult standards', 'lounge', 'swing', 'vocal jazz']
# 440
# []
# 441
# ['adult standards', 'big band', 'lounge', 'swing', 'vocal jazz']
# 442
# ['adult standards', 'brill building pop', 'doo-wop', 'lounge', 'rhythm and blues', 'rock-and-roll', 'rockabilly', 'vocal jazz']
# 443
# ['hip hop', 'pop', 'pop rap', 'rap', 'southern hip hop', 'trap music']
# 444
# ['hollywood', 'post-teen pop', 'show tunes']
# 445
# ['broadway', 'hollywood', 'show tunes']
# 448
# ['atl hip hop', 'dirty south rap', 'hip hop', 'pop rap', 'rap', 'southern hip hop']
# 449
# ['disco', 'mellow gold', 'soft rock']
# 450
# ['dance pop', 'pop rap', 'reggae fusion']
# 451
# ['classic rock', 'dance rock', 'new wave', 'permanent wave', 'punk', 'rock']
# 452
# ['dance pop', 'dance rock', 'disco', 'europop', 'mellow gold', 'new romantic', 'new wave', 'new wave pop', 'rock', 'soft rock', 'synthpop']
# 453
# ['classic soul', 'jazz blues', 'memphis soul', 'soul', 'southern soul']
# 454
# ['british invasion', 'merseybeat', 'psychedelic rock', 'rock']
# 455
# ['album rock', 'mellow gold', 'rock', 'soft rock', 'yacht rock']
# 456
# ['deep talent show', 'hollywood', 'movie tunes']
# 458
# ['talent show']
# 459
# ['rap', 'trap music']
# 460
# ['gospel r&b', 'hip pop', 'r&b', 'urban contemporary']
# 462
# ['dance pop', 'pop', 'post-teen pop', 'r&b', 'viral pop']
# 463
# ['conscious hip hop', 'gangster rap', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap music', 'underground hip hop']
# 464
# ['irish rock', 'pop rock', 'rock']
# 466
# ['italian hip hop']
# 467
# ['swedish gangsta rap', 'uk hip hop']
# 468
# ['edm', 'pop rap', 'rap', 'southern hip hop', 'trap music', 'underground hip hop']
# 469
# ['baile pop', 'funk carioca']
# 470
# ['dance pop', 'pop', 'post-teen pop']
# 471
# ['italian hip hop', 'milan indie', 'rap tunisien']
# 472
# ['chilean hardcore']
# 473
# ['electropop', 'indie poptimism', 'indietronica', 'metropopolis', 'modern rock', 'neo-synthpop', 'shimmer pop']
# 474
# ['indonesian hip hop', 'underground hip hop']
# 475
# ['j-pop girl group', 'k-pop', 'k-pop girl group']
# 476
# ['hip hop', 'pop', 'pop rap', 'rap', 'southern hip hop', 'trap music', 'underground hip hop']
# 477
# ['hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap music', 'vapor trap']
# 478
# ['conscious hip hop', 'escape room', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'underground hip hop']
# 479
# ['cali rap', 'trap music', 'vapor trap', 'west coast trap']
# 480
# ['pop', 'r&b', 'uk contemporary r&b']
# 481
# ['alternative hip hop', 'conscious hip hop', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'underground hip hop']
# 482
# ['alternative r&b', 'gqom']
# 483
# ['cali rap', 'trap music', 'west coast trap']
# 485
# ['dance pop', 'latin', 'latin pop', 'mexican pop', 'pop']
# 486
# ['latin', 'latin arena pop', 'latin pop', 'mexican pop', 'pop', 'reggaeton']
# 487
# ['indie anthem-folk', 'pop']
# 488
# ['east coast hip hop', 'hip hop', 'pop', 'pop rap', 'rap', 'southern hip hop', 'trap music']
# 489
# ['australian pop', 'electropop', 'indie electro-pop', 'indie poptimism', 'metropopolis', 'vapor soul']
# 490
# ['boy band', 'dance pop', 'pop', 'post-teen pop']
# 492
# ['latin', 'latin pop', 'pop']
# 493
# ['canadian hip hop', 'hip hop', 'pop', 'pop rap', 'rap', 'southern hip hop', 'toronto rap', 'trap music']
# 494
# ['k-hop', 'k-pop']
# 496
# ['dance pop', 'gauze pop', 'pop', 'tropical house', 'uk pop']
# 497
# ['australian pop', 'pop', 'post-teen pop']
# 498
# ['israeli pop']
# 499
# []
# 500
# ['dance pop', 'electropop', 'indie cafe pop', 'nyc pop', 'pop']
# 501
# ['pop rap', 'rap']
# 502
# ['argentine hip hop', 'trap argentino']
# 503
# ['baroque pop', 'emo', 'modern rock', 'pop punk']
# 504
# ['dance pop', 'electropop', 'pop', 'post-teen pop', 'r&b']
# 505
# ['contemporary country']
# 506
# ['dance pop', 'electropop', 'indie poptimism', 'pop', 'post-teen pop']
# 508
# ['deep pop r&b']
# 510
# ['australian pop', 'dance pop', 'edm', 'electropop', 'pop', 'pop edm', 'post-teen pop', 'tropical house']
# 511
# ['baroque pop', 'chamber pop', 'dance pop', 'folk-pop', 'pop', 'uk alternative pop']
# 512
# ['latin', 'latin hip hop', 'reggaeton flow', 'tropical']
# 513
# ['sertanejo', 'sertanejo universitario']
# 514
# ['baile pop', 'funk carioca', 'funk ostentacao']
# 515
# ['bachata', 'latin', 'latin pop', 'tropical']
# 516
# ['electropop', 'pop']
# 517
# ['italian hip hop']
# 518
# ['dance pop', 'edm', 'norwegian pop', 'pop', 'pop edm', 'tropical house']
# 519
# ['big room', 'edm', 'progressive electro house']
# 520
# ['basshall']
# 521
# ['country']
# 522
# ['german hip hop']
# 523
# ['deep german hip hop', 'german hip hop', 'hamburg hip hop']
# 524
# ['baile pop', 'funk carioca', 'funk ostentacao']
# 525
# ['baile pop', 'funk carioca', 'funk ostentacao']
# 526
# ['argentine hip hop', 'trap argentino', 'trap latino']
# 527
# ['italian hip hop']
# 528
# ['australian pop', 'dance pop', 'europop', 'pop', 'post-teen pop', 'r&b']
# 529
# ['dance pop', 'pop', 'post-teen pop', 'tropical house', 'uk pop']
# 530
# ['italian arena pop', 'italian hip hop', 'italian pop']
# 531
# ['latin pop']
# 532
# ['garage rock', 'indie rock', 'modern rock', 'permanent wave', 'rock', 'sheffield indie']
# 533
# ['italian alternative', 'italian hip hop', 'trap italiana']
# 534
# ['chicago rap', 'trap music']
# 535
# ['eurovision', 'israeli pop']
# 536
# ['eurovision', 'greek pop', 'laiko']
# 537
# ['czech pop', 'eurovision']
# 538
# ['german pop', 'indie cafe pop', 'viral pop']
# 539
# ['swedish pop']
# 540
# ['detroit hip hop', 'detroit trap', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap music']
# 541
# ['atl hip hop', 'atl trap', 'rap', 'trap music']
# 542
# ['bolero', 'latin', 'latin pop']
# 544
# ['brega funk', 'forro', 'funk carioca', 'sertanejo pop']
# 545
# ['dance pop', 'edm', 'house', 'pop', 'tropical house']
# 546
# ['gangster rap', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap music', 'underground hip hop']
# 547
# ['pop nacional', 'sertanejo universitario']
# 549
# ['modern alternative rock', 'nu gaze', 'pop', 'shiver pop']
# 550
# ['contemporary country', 'country', 'country pop', 'country road', 'modern country rock']
# 551
# ['hip hop', 'pop rap', 'rap']
# 552
# ['german hip hop']
# 553
# ['brega funk', 'funk carioca', 'funk ostentacao']
# 554
# ['edm', 'electropop', 'indie poptimism', 'pop', 'tropical house', 'vapor soul']
# 555
# ['belgian hip hop', 'french hip hop', 'rap conscient', 'trap francais']
# 556
# ['j-pop girl group', 'k-pop', 'k-pop girl group']
# 558
# ['pop', 'post-teen pop', 'r&b', 'uk contemporary r&b']
# 559
# ['pop', 'pop rap', 'r&b', 'urban contemporary']
# 560
# ['french hip hop', 'trap francais']
# 561
# ['baile pop', 'funk carioca', 'funk das antigas']
# 562
# ['pop']
# 563
# ['cali rap', 'hip hop', 'pop', 'pop rap', 'rap', 'southern hip hop', 'trap music']
# 564
# ['latin', 'reggaeton flow', 'trap latino', 'tropical']
# 565
# ['dance pop', 'tropical house']
# 566
# ['edm']
# 567
# ['deep german hip hop', 'german hip hop']
# 568
# []
# 569
# ['hip hop', 'philly rap', 'pop', 'pop rap', 'rap', 'southern hip hop', 'trap music']
# 570
# ['latin', 'reggaeton', 'reggaeton flow', 'tropical']
# 572
# ['dance pop', 'edm', 'pop', 'post-teen pop', 'tropical house']
# 574
# ['reggaeton flow', 'trap latino']
# 575
# ['latin hip hop', 'reggaeton flow', 'trap latino']
# 576
# ['house']
# 577
# ['australian pop', 'pop']
# 578
# ['latin pop', 'latin talent show', 'spanish pop']
# 579
# ['dutch house', 'dutch pop', 'tropical house']
# 580
# ['trap music']
# 584
# ['german hip hop', 'hamburg hip hop']
# 585
# ['dance pop', 'electropop', 'pop', 'scandipop', 'swedish electropop', 'swedish pop', 'tropical house']
# 586
# ['hip hop', 'pittsburgh rap', 'pop rap', 'rap']
# 587
# ['miami hip hop', 'rap', 'southern hip hop', 'trap music', 'underground hip hop', 'vapor trap']
# 588
# ['atl hip hop', 'hip hop', 'pop', 'pop rap', 'rap', 'southern hip hop', 'trap music']
# 589
# ['rap', 'trap music', 'underground hip hop', 'vapor trap']
# 590
# ['edm', 'progressive house', 'progressive trance', 'trance']
# 591
# ['viral pop']
# 592
# ['dance rock', 'new romantic', 'new wave', 'new wave pop', 'permanent wave', 'soft rock', 'synthpop']
# 593
# ['melodic metalcore', 'metalcore', 'rock', 'screamo', 'uk metalcore']
# 594
# ['hip hop', 'pop rap', 'rap', 'southern hip hop', 'underground hip hop']
# 595
# ['pop', 'pop rap']
# 596
# ['boy band', 'dance pop', 'pop', 'post-teen pop', 'teen pop']
# 598
# ['rap conscient', 'trap music', 'vapor trap']
# 599
# ['pop rap']
# 600
# ['edm', 'house', 'tropical house']
# 601
# ['dutch hip hop', 'dutch pop']
# 602
# ['rap', 'trap music', 'underground hip hop', 'vapor trap']
# 603
# ['italian hip hop']
# 604
# ['alternative r&b', 'viral pop']
# 605
# ['german hip hop']
# 607
# ['trap music', 'trap soul']
# 608
# ['folk-pop', 'modern rock', 'stomp and holler', 'uk americana']
# 609
# ['german hip hop']
# 610
# ['boy band', 'hip hop', 'pop rap', 'rap']
# 611
# ['canadian pop', 'candy pop', 'dance pop', 'pop', 'post-teen pop']
# 612
# ['albanian hip hop', 'deep german hip hop', 'german hip hop']
# 613
# ['dance pop', 'pop', 'post-teen pop']
# 614
# ['ccm', 'christian music', 'worship']
# 615
# ['escape room']
# 616
# ['atl hip hop', 'hip hop', 'rap', 'southern hip hop', 'trap music']
# 617
# ['latin', 'reggaeton flow', 'trap latino', 'tropical']
# 618
# ['latin', 'latin pop', 'modern salsa', 'salsa', 'tropical']
# 619
# ['latin', 'latin hip hop', 'reggaeton', 'reggaeton flow', 'tropical']
# 620
# ['german hip hop']
# 621
# ['k-hop', 'k-pop']
# 622
# ['r&b']
# 623
# ['pop', 'post-teen pop', 'r&b']
# 624
# ['atl hip hop', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap music']
# 626
# ['colombian pop', 'latin pop']
# 627
# ['german hip hop']
# 628
# ['alternative metal', 'industrial', 'industrial metal', 'industrial rock', 'nu metal', 'post-grunge', 'rock', 'wrestling']
# 629
# ['gangster rap', 'hip hop', 'old school hip hop', 'philly rap', 'rap']
# 630
# ['italian arena pop', 'italian hip hop', 'italian pop']
# 631
# ['canadian pop', 'dance pop', 'electropop', 'indie poptimism', 'pop', 'post-teen pop', 'r&b']
# 632
# ['k-pop girl group']
# 634
# ['k-pop']
# 635
# ['belgian hip hop', 'french hip hop', 'rap conscient']
# 636
# ['atl hip hop', 'hip hop', 'pop', 'pop rap', 'rap', 'southern hip hop', 'trap music']
# 637
# []
# 638
# ['electro latino', 'latin', 'latin hip hop', 'reggaeton', 'tropical']
# 639
# ['funk carioca', 'funk ostentacao']
# 640
# ['german hip hop']
# 641
# ['miami hip hop', 'rap', 'trap music', 'underground hip hop']
# 642
# ['contemporary country', 'country', 'country road', 'modern country rock']
# 643
# ['big band', 'cool jazz', 'swing']
# 644
# ['pop', 'r&b']
# 645
# ['indie cafe pop']
# 646
# ['albanian hip hop', 'german hip hop']
# 647
# ['boy band', 'dance pop', 'europop']
# 648
# ['adult standards', 'jazz blues', 'swing', 'vocal jazz']
# 649
# ['neo mellow', 'pop', 'pop rock']
# 650
# ['australian pop', 'dance pop', 'electropop', 'indie cafe pop', 'neo-singer-songwriter', 'pop', 'post-teen pop', 'uk pop', 'viral pop']
# 651
# ['australian pop', 'dance pop', 'pop', 'pop rap', 'post-teen pop', 'r&b', 'viral pop']
# 653
# ['chicago soul', 'classic soul', 'funk', 'motown', 'neo soul', 'quiet storm', 'r&b', 'soul', 'southern soul', 'vocal jazz']
# 655
# ['contemporary country', 'country pop', 'modern country rock']
# 656
# ['adult standards', 'brill building pop', 'easy listening', 'lounge', 'mellow gold', 'operatic pop', 'vocal jazz']
# 657
# ['hip house', 'new wave pop']
# 658
# ['anthem worship', 'ccm', 'christian alternative rock', 'christian music', 'worship']
# 659
# ['german hip hop', 'hamburg hip hop']
# 660
# ['baile pop', 'brazilian edm', 'funk carioca', 'funk das antigas', 'funk ostentacao']
# 662
# ['sertanejo', 'sertanejo pop', 'sertanejo universitario']
# 663
# ['dance pop', 'pop', 'r&b']
# 664
# ['forro', 'funk carioca', 'sertanejo pop']
# 665
# ['funk carioca']
# 666
# ['sertanejo universitario']
# 667
# ['electropop']
# 668
# ['pop']
# 669
# ['destroy techno']
# 670
# ['german hip hop']
# 671
# ['dance pop', 'pop', 'post-teen pop', 'r&b', 'rap']
# 672
# ['italian arena pop', 'italian hip hop', 'italian pop', 'rap napoletano', 'rome indie']
# 673
# ['indie r&b', 'indietronica', 'uk alternative pop']
# 674
# ['italian hip hop', 'rap napoletano']
# 675
# ['cali rap', 'hip hop', 'pop', 'pop rap', 'rap', 'southern hip hop', 'trap music']
# 677
# ['baroque pop', 'folk-pop', 'indie folk', 'indie pop', 'indie rock', 'modern rock']
# 678
# []
# 679
# ['cali rap']
# 680
# ['turkish pop']
# 681
# ['alternative pop rock']
# 682
# ['dance pop', 'pop', 'post-teen pop', 'r&b', 'tropical house', 'uk pop']
# 683
# ['reggaeton flow', 'trap brasileiro']
# 686
# ['italian arena pop']
# 687
# ['italian arena pop', 'italian pop']
# 688
# ['trap music']
# 689
# ['album rock', 'classic rock', 'dance rock', 'mellow gold', 'permanent wave', 'rock', 'soft rock']
# 690
# ['hip pop', 'neo soul', 'pop', 'r&b', 'urban contemporary']
# 691
# ['british indie rock']
# 692
# ['german hip hop']
# 693
# ['colombian hip hop', 'colombian pop', 'cumbia', 'latin', 'latin alternative', 'latin pop', 'latin rock']
# 694
# ['reggaeton flow']
# 695
# ['dominican pop', 'rap dominicano', 'reggaeton flow']
# 696
# ['indie folk']
# 697
# ['baile pop', 'bass trap', 'funk carioca', 'pop nacional']
# 698
# ['french hip hop', 'trap francais']
# 699
# ['chicago rap', 'trap music']
# 700
# ['alternative r&b', 'deep pop r&b', 'indie r&b', 'pop', 'r&b']
# 701
# ['boy band', 'dance pop', 'pop', 'post-teen pop']
# 702
# ['alternative r&b', 'escape room', 'hip pop', 'neo soul', 'pop', 'r&b', 'urban contemporary']
# 703
# ['r&b en espanol']
# 704
# ['panamanian pop', 'reggaeton flow']
# 705
# ['chicago house']
# 706
# ['k-pop']
# 707
# ['country rap']
# 708
# ['alternative rock', 'blues-rock', 'garage rock', 'indie rock', 'modern blues rock', 'modern rock', 'punk blues', 'rock']
# 709
# ['latin', 'reggaeton flow', 'tropical']
# 710
# ['trap espanol']
# 711
# ['swedish pop']
# 712
# ['contemporary country']
# 713
# ['dance pop', 'electropop', 'indie cafe pop', 'indie electro-pop', 'indie poptimism', 'pop', 'post-teen pop', 'uk pop']
# 714
# ['reggaeton flow', 'trap latino']
# 715
# ['reggaeton flow']
# 716
# ['german cloud rap', 'german hip hop']
# 717
# ['australian psych', 'neo-psychedelic', 'psychedelic rock']
# 718
# ['latin pop', 'reggaeton chileno', 'trap chileno']
# 719
# ['german hip hop']
# 720
# ['lithuanian electronic']
# 722
# ['alternative metal', 'german metal', 'industrial', 'industrial metal', 'industrial rock', 'neue deutsche harte']
# 723
# ['latin', 'reggaeton flow', 'tropical']
# 724
# ['conscious hip hop', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap music']
# 725
# ['bachata', 'latin', 'latin hip hop', 'latin pop', 'tropical']
# 726
# ['albanian hip hop', 'german hip hop']
# 727
# ['panamanian pop']
# 728
# ['reggaeton flow']
# 729
# ['pop house']
# 730
# ['chicago rap']
# 731
# ['dance pop']
# 732
# ['j-pop girl group', 'k-pop', 'k-pop girl group']
# 733
# ['dance pop', 'escape room', 'minnesota hip hop', 'pop', 'trap queen']
# 734
# ['nc hip hop', 'rap', 'trap music']
# 735
# ['lo-fi beats']

# %%
placeholder_list = list(set(placeholder_list))

# %%
placeholder_list
# Out:
# ['screamo',
#  'jazz trio',
#  'shimmer pop',
#  'country rap',
#  'philly rap',
#  'soul',
#  'milan indie',
#  'israeli pop',
#  'dominican pop',
#  'dance rock',
#  'ninja',
#  'pop reggaeton',
#  'funk ostentacao',
#  'viral pop',
#  'progressive house',
#  'vapor soul',
#  'industrial metal',
#  'modern alternative rock',
#  'yacht rock',
#  'british soul',
#  'indonesian hip hop',
#  'canadian electronic',
#  'trap espanol',
#  'metalcore',
#  'belgian edm',
#  'neo soul',
#  'classic uk pop',
#  'swedish tropical house',
#  'rome indie',
#  'symphonic rock',
#  'danish pop',
#  'ccm',
#  'eurodance',
#  'grunge',
#  'funk metal',
#  'uk hip hop',
#  'latin talent show',
#  'scandipop',
#  'salsa',
#  'irish singer-songwriter',
#  'classic soul',
#  'eau claire indie',
#  'australian psych',
#  'hip house',
#  'adult standards',
#  'laiko',
#  'industrial rock',
#  'vocal house',
#  'american folk revival',
#  'cool jazz',
#  'bachata',
#  'reggae fusion',
#  'roots rock',
#  'rap napoletano',
#  'australian rock',
#  'indie r&b',
#  'soft rock',
#  'italian underground hip hop',
#  'country',
#  'indie anthem-folk',
#  'italian arena pop',
#  'toronto rap',
#  'old school hip hop',
#  'rap',
#  'portland hip hop',
#  'indie electro-pop',
#  'pop',
#  'uk metalcore',
#  'brega funk',
#  'portuguese pop',
#  'rap sardegna',
#  'gangster rap',
#  'german pop',
#  'west coast rap',
#  'shiver pop',
#  'neue deutsche harte',
#  'rap metal',
#  'southern hip hop',
#  'trap latino',
#  'cubaton',
#  'canadian singer-songwriter',
#  'rap conscient',
#  'pop nacional',
#  'tropical',
#  'christian alternative rock',
#  'indie pop rap',
#  'bass trap',
#  'chamber pop',
#  'pop punk',
#  'norwegian pop',
#  'san diego rap',
#  'brostep',
#  'post-grunge',
#  'quiet storm',
#  'mellow gold',
#  'disco',
#  'funk das antigas',
#  'azonto',
#  'indie rock',
#  'nigerian pop',
#  'dance-punk',
#  'hollywood',
#  'rap dominicano',
#  'modern blues rock',
#  'trance',
#  'deep big room',
#  'traditional country',
#  'swedish pop',
#  'minnesota hip hop',
#  'alternative r&b',
#  'dmv rap',
#  'talent show',
#  'belgian hip hop',
#  'ranchera',
#  'detroit hip hop',
#  'deep adult standards',
#  'french hip hop',
#  'modern country rock',
#  'sunshine pop',
#  'big band',
#  'german cloud rap',
#  'piano rock',
#  'motown',
#  'indie cafe pop',
#  'psychedelic rock',
#  'boy band',
#  'channel islands indie',
#  'forro',
#  'synthpop',
#  'worship',
#  'country road',
#  'r&b',
#  'industrial',
#  'afropop',
#  'punk blues',
#  'cali rap',
#  'post-teen pop',
#  'pop edm',
#  'gauze pop',
#  'urban contemporary',
#  'trap queen',
#  'k-pop girl group',
#  'danish electronic',
#  'glam rock',
#  'grime',
#  'sheffield indie',
#  'movie tunes',
#  'emo',
#  'folk rock',
#  'irish rock',
#  'new rave',
#  'irish folk',
#  'nottingham indie',
#  'big room',
#  'indie poptimism',
#  'indie folk',
#  'conscious hip hop',
#  'uk pop',
#  'house',
#  'jazz funk',
#  'celtic',
#  'nu metal',
#  'punk',
#  'uk dance',
#  'electro',
#  'lo-fi beats',
#  'brill building pop',
#  'rap tunisien',
#  'dutch pop',
#  'latin hip hop',
#  'soca',
#  'filter house',
#  'broadway',
#  'bmore',
#  'indie pop',
#  'lgbtq+ hip hop',
#  'vocal jazz',
#  'uk americana',
#  'slow core',
#  'latin rock',
#  'melodic metalcore',
#  'operatic pop',
#  'italian alternative',
#  'mexican pop',
#  'new romantic',
#  'deep euro house',
#  'hip pop',
#  'colombian hip hop',
#  'dance pop',
#  'nu disco',
#  'nyc pop',
#  'album rock',
#  'nu gaze',
#  'funk carioca',
#  'new americana',
#  'art rock',
#  'a cappella',
#  'complextro',
#  'vallenato',
#  'chilean hardcore',
#  'baroque pop',
#  'hyphy',
#  'swedish electropop',
#  'trap francais',
#  'christian music',
#  'jazz blues',
#  'vapor pop',
#  'australian electropop',
#  'escape room',
#  'new wave',
#  'deep talent show',
#  'deep tropical house',
#  'reggaeton flow',
#  'deep pop r&b',
#  'trap chileno',
#  'cumbia',
#  'alternative rock',
#  'hard rock',
#  'latin viral pop',
#  'chicano rap',
#  'sertanejo',
#  'alabama rap',
#  'progressive electro house',
#  'uk funky',
#  'candy pop',
#  'ukrainian classical',
#  'cowboy western',
#  'r&b en espanol',
#  'icelandic indie',
#  'modern rock',
#  'canadian contemporary r&b',
#  'sertanejo universitario',
#  'garage rock',
#  'celtic punk',
#  'rockabilly',
#  'destroy techno',
#  'latin pop',
#  'deep house',
#  'celtic rock',
#  'czech pop',
#  'alternative hip hop',
#  'blues-rock',
#  'art pop',
#  'belgian dance',
#  'drill',
#  'alternative metal',
#  'atl hip hop',
#  'basshall',
#  'baile pop',
#  'pop house',
#  'chicago rap',
#  'bow pop',
#  'reggaeton',
#  'dirty south rap',
#  'uk contemporary r&b',
#  'australian indie',
#  'permanent wave',
#  'greek pop',
#  'neo-singer-songwriter',
#  'k-hop',
#  'florida rap',
#  'hands up',
#  'britpop',
#  'g funk',
#  'pop rock',
#  'alternative pop rock',
#  'dutch hip hop',
#  'trap soul',
#  'hardcore hip hop',
#  'liquid funk',
#  'australian pop',
#  'rhythm and blues',
#  'dancehall',
#  'chicago soul',
#  'folk-pop',
#  'german hip hop',
#  'memphis soul',
#  'canadian pop',
#  'electronic trap',
#  'bubblegum pop',
#  'swedish gangsta rap',
#  'lounge',
#  'new wave pop',
#  'la pop',
#  'teen pop',
#  'indietronica',
#  'merseybeat',
#  'western swing',
#  'german metal',
#  'hamburg hip hop',
#  'electro latino',
#  'ballroom',
#  'disco house',
#  'neo-psychedelic',
#  'pop emo',
#  'funk',
#  'k-pop boy group',
#  'latin arena pop',
#  'atl trap',
#  'gospel r&b',
#  'funky tech house',
#  'champeta',
#  'east coast hip hop',
#  'pop rap',
#  'j-pop girl group',
#  'latin alternative',
#  'nigerian hip hop',
#  'edm',
#  'sky room',
#  'europop',
#  'brooklyn indie',
#  'downtempo',
#  'classic canadian rock',
#  'heartland rock',
#  'west coast trap',
#  'german techno',
#  'panamanian pop',
#  'electropop',
#  'metropopolis',
#  'swedish idol pop',
#  'modern salsa',
#  'detroit trap',
#  'etherpop',
#  'argentine hip hop',
#  'classic rock',
#  'miami hip hop',
#  'nc hip hop',
#  'viral trap',
#  'aussietronica',
#  'italo dance',
#  'sertanejo pop',
#  'british indie rock',
#  'australian hip hop',
#  'stomp and holler',
#  'bolero',
#  'trap argentino',
#  'neo-synthpop',
#  'chicago house',
#  'folk',
#  'easy listening',
#  'swedish synthpop',
#  'pixie',
#  'deep german hip hop',
#  'anthem worship',
#  'progressive trance',
#  'melancholia',
#  'italian pop',
#  'memphis hip hop',
#  'swing',
#  'electro house',
#  'nyc rap',
#  'northern soul',
#  'turkish pop',
#  'emo rap',
#  'moombahton',
#  'new orleans rap',
#  'k-pop',
#  'singer-songwriter',
#  'show tunes',
#  'underground hip hop',
#  'hip hop',
#  'madchester',
#  'german dance',
#  'trap brasileiro',
#  'country rock',
#  'lilith',
#  'brazilian edm',
#  'latin',
#  'post-romantic era',
#  'trap italiana',
#  'albanian hip hop',
#  'canadian hip hop',
#  'afro dancehall',
#  'folk punk',
#  'vapor twitch',
#  'british invasion',
#  'dream pop',
#  'doo-wop',
#  'dfw rap',
#  'reggaeton chileno',
#  'australian dance',
#  'contemporary country',
#  'eurovision',
#  'tropical house',
#  'neo mellow',
#  'classic girl group',
#  'southern rock',
#  'new french touch',
#  'nashville sound',
#  'southern soul',
#  'rock',
#  'trap music',
#  'spanish pop',
#  'dutch house',
#  'italian hip hop',
#  'wrestling',
#  'gqom',
#  'electropowerpop',
#  'acoustic pop',
#  'uk alternative pop',
#  'nz pop',
#  'pittsburgh rap',
#  'country pop',
#  'girl group',
#  'colombian pop',
#  'lithuanian electronic',
#  'vapor trap',
#  'rock-and-roll',
#  'alternative dance',
#  'post-disco']

# %%
len(placeholder_list)
# Out:
# 410

# %%
d = defaultdict(int)
for x in range(len(unique_genres)):
    if type(unique_genres.iloc[x]['genres']) != float:
        for genre in unique_genres.iloc[x]['genres']:
            d[genre] +=1

# %%
result = sorted(d.items(), key=lambda kv: kv[1], reverse=True)
print (result)
# Out:
# [('pop', 268), ('dance pop', 156), ('rap', 104), ('pop rap', 102), ('post-teen pop', 91), ('trap music', 75), ('tropical house', 71), ('hip hop', 65), ('r&b', 55), ('edm', 54), ('latin', 50), ('southern hip hop', 47), ('rock', 44), ('electropop', 38), ('tropical', 37), ('latin pop', 32), ('reggaeton', 28), ('electro house', 25), ('modern rock', 25), ('underground hip hop', 24), ('mellow gold', 23), ('reggaeton flow', 21), ('german hip hop', 21), ('adult standards', 21), ('australian pop', 20), ('soft rock', 20), ('funk carioca', 19), ('indie poptimism', 19), ('atl hip hop', 18), ('pop rock', 18), ('viral pop', 17), ('latin hip hop', 17), ('neo mellow', 16), ('permanent wave', 16), ('album rock', 16), ('lounge', 16), ('vocal jazz', 16), ('big room', 15), ('classic rock', 15), ('pop edm', 14), ('europop', 14), ('uk pop', 13), ('urban contemporary', 12), ('swedish pop', 11), ('funk ostentacao', 11), ('trap latino', 11), ('vapor trap', 11), ('baile pop', 11), ('italian hip hop', 11), ('metropopolis', 10), ('post-grunge', 10), ('new wave pop', 10), ('brill building pop', 10), ('easy listening', 10), ('colombian pop', 9), ('mexican pop', 9), ('conscious hip hop', 9), ('k-pop', 9), ('canadian pop', 8), ('house', 8), ('boy band', 8), ('gangster rap', 8), ('indie pop', 8), ('indie rock', 8), ('miami hip hop', 8), ('folk-pop', 8), ('indietronica', 8), ('contemporary country', 8), ('hip pop', 8), ('folk rock', 8), ('uk dance', 7), ('indie cafe pop', 7), ('motown', 7), ('progressive electro house', 7), ('hard rock', 7), ('alternative rock', 7), ('alternative metal', 7), ('disco', 7), ('talent show', 6), ('neo soul', 6), ('chicago rap', 6), ('soul', 6), ('hollywood', 6), ('alternative r&b', 6), ('eurovision', 6), ('rock-and-roll', 6), ('rockabilly', 6), ('cali rap', 6), ('french hip hop', 6), ('dance rock', 6), ('pop punk', 5), ('deep tropical house', 5), ('glam rock', 5), ('quiet storm', 5), ('escape room', 5), ('emo rap', 5), ('indie folk', 5), ('art rock', 5), ('trap francais', 5), ('heartland rock', 5), ('psychedelic rock', 5), ('new wave', 5), ('swing', 5), ('italian arena pop', 5), ('toronto rap', 4), ('progressive house', 4), ('australian dance', 4), ('scandipop', 4), ('swedish electropop', 4), ('pop nacional', 4), ('funk das antigas', 4), ('indie r&b', 4), ('indie electro-pop', 4), ('funk', 4), ('deep big room', 4), ('vapor soul', 4), ('norwegian pop', 4), ('nu metal', 4), ('latin arena pop', 4), ('bachata', 4), ('yacht rock', 4), ('country', 4), ('country road', 4), ('modern country rock', 4), ('blues-rock', 4), ('deep german hip hop', 4), ('hamburg hip hop', 4), ('new romantic', 4), ('big band', 4), ('rap conscient', 4), ('baroque pop', 4), ('k-pop girl group', 4), ('sertanejo universitario', 4), ('italian pop', 4), ('canadian hip hop', 3), ('girl group', 3), ('west coast trap', 3), ('detroit hip hop', 3), ('british soul', 3), ('brega funk', 3), ('lgbtq+ hip hop', 3), ('downtempo', 3), ('electro latino', 3), ('philly rap', 3), ('classic soul', 3), ('brostep', 3), ('new rave', 3), ('east coast hip hop', 3), ('dirty south rap', 3), ('singer-songwriter', 3), ('country pop', 3), ('irish rock', 3), ('stomp and holler', 3), ('candy pop', 3), ('emo', 3), ('piano rock', 3), ('latin viral pop', 3), ('panamanian pop', 3), ('roots rock', 3), ('belgian hip hop', 3), ('j-pop girl group', 3), ('sertanejo pop', 3), ('albanian hip hop', 3), ('canadian contemporary r&b', 2), ('electronic trap', 2), ('uk funky', 2), ('moombahton', 2), ('brazilian edm', 2), ('german dance', 2), ('champeta', 2), ('nc hip hop', 2), ('swedish tropical house', 2), ('danish pop', 2), ('shiver pop', 2), ('indie pop rap', 2), ('la pop', 2), ('cubaton', 2), ('pop reggaeton', 2), ('atl trap', 2), ('dancehall', 2), ('bass trap', 2), ('complextro', 2), ('swedish synthpop', 2), ('dfw rap', 2), ('german pop', 2), ('nyc pop', 2), ('trance', 2), ('movie tunes', 2), ('german techno', 2), ('modern alternative rock', 2), ('k-pop boy group', 2), ('chamber pop', 2), ('alternative danc ...

# %%
import matplotlib.pyplot as plt

# %%
from collections import Counter

# %%
scores = Counter(result)
scores = scores.most_common(10)

# %%
popular = result

# %%
print (scores)
# Out:
# [(('pop', 268), 1), (('dance pop', 156), 1), (('rap', 104), 1), (('pop rap', 102), 1), (('post-teen pop', 91), 1), (('trap music', 75), 1), (('tropical house', 71), 1), (('hip hop', 65), 1), (('r&b', 55), 1), (('edm', 54), 1)]

# %%
x,y = zip(*scores)
x,y = zip(*x)

# %%
_ = plt.figure(figsize=(20,10))
_ = plt.plot(x,y)

# %%
song_analysis = pd.read_csv(r'C:\Users\abels\Desktop\spotify_scrape\Data\final_csv_files\song_analysis_data.csv')
song_analysis.head()

# %%
df['track_id'] = df['URL'].str[32:1000]
df.head()

# %%
df.merge(song_analysis, how='inner', left_on='track_id', right_on='id')
df.head()
